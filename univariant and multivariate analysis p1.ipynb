# %% [markdown]
# # Univariate: univariate analysis refers to the analysis of a single variable in a dataset. The purpose is to understand the distribution ,central tendency and spread of the data for that particular variable.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\user\Downloads\train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Categorical data:Categorical data refers to variables that represent categories or groups rather than numerical values. These categories describe qualities or characteristics and are often used to label data.

# %%
#count plot
sns.countplot(x=df['Survived'])#no. of repetation value
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Pclass'])#no. of repetation value
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Embarked'])#no. of repetation value
df['Embarked'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object>

# %%
sns.countplot(x=df['Sex'])#no. of repetation value
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
#pie chart
df['Survived'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical Data:Numerical data refers to data that is represented by numbers and can be measured or counted. It’s used to quantify things and allows for mathematical operations like addition, subtraction, averaging, and more.

# %%
#Histogram
sns.histplot(x=df['Age'],bins=20,color='Purple')
plt.title("Distribution of Age")
plt.show()

# %% [markdown]
# # kde : kernel density estimator method used to estimate the probability density function of continous randon variable. It provide a smooth

# %%
# hist plot
sns.histplot(x=df['Age'],kde=True,stat='density')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(x=df['Age'],fill=True)
plt.show()

# %% [raw]
# panda:data cleaning and manupulation
# numpy:data cleaning

# %%
# Box plot
sns.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
df['Age'].value_counts()#to count value of the column
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
print(df['Age'].min())
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %% [markdown]
# # Bivariant /Multivariant Analysis:Multivariate analysis refers to a set of statistical techniques used to examine data that involves more than one variable at a time. It helps uncover relationships, patterns, and dependencies between variables, which is especially useful when trying to understand complex datasets.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips=sns.load_dataset('tips')
titanic=pd.read_csv(r"C:\Users\user\Downloads\train.csv")
flights=sns.load_dataset('flights')

# %% [markdown]
# ## Scatterplot(Numeric-numeric)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue=tips['sex'],style=tips['smoker'],size=tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## Bar plot( categorial-numerical)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# A barplot is usefull for showing the average value of a numerical variable across different
# categories of a categorial variable
sns.barplot(x=titanic['Pclass'],y=titanic['Age'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
male_passenger=titanic[titanic['Sex']=='male']
male_passenger['Age'].mean()
# Out:
# np.float64(30.72664459161148)

# %%
male_passenger=titanic[titanic['Sex']=='female']
male_passenger['Age'].mean()
# Out:
# np.float64(27.915708812260537)

# %%
p1=titanic[(titanic['Pclass']==1)&(titanic['Sex']=='female')]
print(f' we have {p1.shape[0]} female passenger in Pclass 1')#without apply shape[0] it show row and column
# Out:
#  we have 94 female passenger in Pclass 1

# %%
p1=titanic[(titanic['Pclass']==1)&(titanic['Sex']=='male')]
print(f' we have {p1.shape[0]} male passenger in Pclass 1')
# Out:
#  we have 122 male passenger in Pclass 1

# %%
# Box plot(categorical-numerical)
sns.boxplot(x=titanic['Sex'],y=titanic['Age'],hue=titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.histplot(x=titanic[titanic['Survived']==0]['Age'],kde=True,stat='density')
sns.histplot(x=titanic[titanic['Survived']==1]['Age'],kde=True,stat='density')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(x=titanic[titanic['Survived']==0]['Age'])
sns.kdeplot(x=titanic[titanic['Survived']==1]['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# HeatMap(Categorical-Categorical)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.crosstab(titanic['Pclass'],titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(titanic.groupby('Pclass')['Survived'].mean()*100)

# %%
(titanic.groupby('Sex')['Survived'].mean()*100).plot(kind='pie',autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Survived'>

# %% [markdown]
# # Clustermap(Categorical-Categorical)

# %%
pd.crosstab(titanic['SibSp'],titanic['Survived'])
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
pip install
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'],titanic['Survived']))

# %% [markdown]
# # Pair plot(Numerical-Numerical)

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data=iris)

# %% [markdown]
# # Line plot

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
new_df=flights.groupby('year')["passengers"].sum().reset_index()

# %%
new_df
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(x=new_df['year'],y=new_df['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
pv=flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14276\3516063986.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pv=flights.pivot_table(values='passengers',index='month',columns='year')

# %%
pv
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
sns.heatmap(data=pv)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(data=pv)
